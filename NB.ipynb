# %%
import numpy as np 
import pandas as pd 
import nltk
from nltk.corpus import stopwords
import string

# %%
df = pd.read_csv('spamdata222.csv')

df = df [["body","target"]]

print(df)
# Out:
#                                                     body  target
# 0      hi, this pr adds keyboardtype parameter to cup...       1
# 1      you are receiving this because you are subscri...       1
# 2      it looks like this pull request may not have t...       1
# 3      what to do if you already signed the cla indiv...       1
# 4      thanks for your pull request. it looks like th...       1
# ...                                                  ...     ...
# 29995  ( see attached file : hplno 516 . xls )\n- hpl...       0
# 29996  ( see attached file : hplno 516 . xls )\n- hpl...       0
# 29997  ( see attached file : hplno 516 . xls )\n- hpl...       0
# 29998  ( see attached file : hplno 516 . xls )\n- hpl...       0
# 29999  ( see attached file : hplno 321 . xls )\n- hpl...       0
#
# [30000 rows x 2 columns]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
def process_text(body):
    
    nopunc = [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)

    clean_words = [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

    return clean_words

# %%
df['body'].head().apply(process_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-147abf80fce3> in <module>()
# ----> 1 df['body'].head().apply(process_text)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-8-c7ed637c28f5> in process_text(body)
#       1 def process_text(body):
#       2
# ----> 3     nopunc = [char for char in text if char not in string.punctuation]
#       4     nopunc = ''.join(nopunc)
#       5
#
# NameError: name 'text' is not defined

# %%
from sklearn.feature_extraction.text import CountVectorizer
messages_bow = CountVectorizer(analyzer=process_text).fit_transform(df['text'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(messages_bow, df['label_num'], test_size = 0.20, random_state = 0)

# %%
from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB()
classifier.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
from sklearn.metrics import accuracy_score
pred = classifier.predict(X_train)

print('Accuracy: ', accuracy_score(y_train,pred))
# Out:
# Accuracy:  0.9874274661508704
